# %%
import matplotlib.pyplot as plt
# @matplotlib inline #Jupyter notebook에서 그래프를 웹페이지 바로 출력하도록 설정하는 명령어
# 별도이 창이 아니라 코드가 실행된 셀 바로 아래에서 그래프 를 출력.
# IPython전용 명령어이므로 .py 파일에서는 오류
# IPython 5 이상에서는 생략 가능. 이전 버전에서는 포함되어 있는 경우가 많음.
import pandas as pd
import numpy as np

plt.plot(np.arange(10))

# %%
from pandas import DataFrame, Series
import pandas as pd

myCampus = Series([100, 200, 300, 400, 500], index=["2026-07-01","2026-07-02","2026-07-03","2026-07-04","2026-07-05"])
print(myCampus)
type(myCampus)
# Out:
# 2026-07-01    100
# 2026-07-02    200
# 2026-07-03    300
# 2026-07-04    400
# 2026-07-05    500
# dtype: int64
# pandas.Series

# %%
sample1 = [["아아폰16", 1500000], ["아아폰15", 1400000], ["아아폰14", 1200000]]
column1 = ["제품명", "가격"]
myFrame1 = DataFrame(data=sample1, columns=column1)

print(myFrame1)
# Out:
#      제품명       가격
# 0  아아폰16  1500000
# 1  아아폰15  1400000
# 2  아아폰14  1200000

# %%
data = {
    "foreigner": [1,2,3,4,5],
    "sratio": [10,20,30,40,50],
    "org": [100,200,300,400,500],
    "sprice": [1,2,3,4,5],
    "private": [10,20,30,40,50]
}
data
# Out:
# {'foreigner': [1, 2, 3, 4, 5],
#  'sratio': [10, 20, 30, 40, 50],
#  'org': [100, 200, 300, 400, 500],
#  'sprice': [1, 2, 3, 4, 5],
#  'private': [10, 20, 30, 40, 50]}

# %%
# 데이터 프레임 생성.

# %%
frame = DataFrame(data)

# %%
type(frame)
# Out:
# pandas.DataFrame

# %%
frame
# Out:
#    foreigner  sratio  org  sprice  private
# 0          1      10  100       1       10
# 1          2      20  200       2       20
# 2          3      30  300       3       30
# 3          4      40  400       4       40
# 4          5      50  500       5       50

# %%
frame2 = DataFrame(data, columns=["foreigner","org","private","sprice","sratio"])
frame2
# Out:
#    foreigner  org  private  sprice  sratio
# 0          1  100       10       1      10
# 1          2  200       20       2      20
# 2          3  300       30       3      30
# 3          4  400       40       4      40
# 4          5  500       50       5      50

# %%
frame3 = DataFrame(data, columns=['foreigner', 'org', 'private','sprice', 'sratio'], index=["2025-07-01", "2025-07-02", "2025-07-03", "2025-07-04", "2025-07-05"])
frame3
# Out:
#             foreigner  org  private  sprice  sratio
# 2025-07-01          1  100       10       1      10
# 2025-07-02          2  200       20       2      20
# 2025-07-03          3  300       30       3      30
# 2025-07-04          4  400       40       4      40
# 2025-07-05          5  500       50       5      50

# %%
frame3["foreigner"]
# Out:
# 2025-07-01    1
# 2025-07-02    2
# 2025-07-03    3
# 2025-07-04    4
# 2025-07-05    5
# Name: foreigner, dtype: int64

# %%
# 첫번째 행데이터를 슬라이싱해서 사용하는 경우.

# %%
frame3["2025-07-01"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\xlimit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
frame3.loc["2025-07-01"]
# Out:
# foreigner      1
# org          100
# private       10
# sprice         1
# sratio        10
# Name: 2025-07-01, dtype: int64

# %%
frame3.transpose()
# Out:
#            2025-07-01  2025-07-02  2025-07-03  2025-07-04  2025-07-05
# foreigner           1           2           3           4           5
# org               100         200         300         400         500
# private            10          20          30          40          50
# sprice              1           2           3           4           5
# sratio             10          20          30          40          50
